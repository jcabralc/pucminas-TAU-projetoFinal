# %% [markdown]
# # Gerar Snapshots das respostas da API
#
# As respostas são salvas em  `data/snapshot_respostas.json`

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# grava snapshot de respostas da API
import scripts.gravar_snapshot as gravar_snapshot

gravar_snapshot.main()
# Out:
# Checando /health...
# {'status': 'ok', 'chromadb': 'ok'}
# 0 já gravadas, 29 pendentes...
# [1/29] tarifa_anuidade_padrao: Qual o valor da anuidade do cartão padrão da Aurora?...
# Cota esgotada em 'tarifa_anuidade_padrao': Cota da API do provedor de IA esgotada. Verifique seu plano e limites de uso nas configurações.
# Parando por aqui — rode de novo mais tarde para completar o restante.
# Snapshot gravado em /mnt/c/git/pucminas-TAU-projetoFinal/data/snapshot_respostas.json
